# %%
times = {
    'PDT_Morning_Track': {
    'ScheduleTrack': 'Track1',
    'TZXM': 'PDT',
    'TZTITLE': 'Morning Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '6 AM',
    'T2XM': '7 AM',
    'T3XM': '7:10 AM',
    'T4XM': '8 AM',
    'T5XM': '8:10 AM',
    'T6XM': '9 AM',
    'T7XM': '10 AM',
    'T8XM': '11 AM',
    'T9XM': '12 PM',
    'T10XM': '1 PM',        
    'T11XM': '9-9:30AM', 
    },
    'PDT_Afternoon_Track': {
    'ScheduleTrack': 'Track2',
    'TZXM': 'PDT',
    'TZTITLE': 'Afternoon Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '2 PM',
    'T2XM': '3 PM',
    'T3XM': '3:10 PM',
    'T4XM': '4 PM',
    'T5XM': '4:10 PM',
    'T6XM': '5 PM',
    'T7XM': '6 PM',
    'T8XM': '7 PM',
    'T9XM': '8 PM',
    'T10XM': '9 PM',
    'T11XM': '5-5:30PM', 
    },
    'PDT_Night_Poster_Session': {
    'ScheduleTrack': 'Track3',
    'TZXM': 'PDT',
    'TZTITLE': 'Night Poster Session',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '1 AM',
    'T2XM': '3 AM',
    'T3XM': '1-1:30 AM',
    'T4XM': '2-2:30 AM',
    },
    'EDT_Morning_Track': {
    'ScheduleTrack': 'Track1',
    'TZXM': 'EDT',
    'TZTITLE': 'Morning Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '9 AM',
    'T2XM': '10 AM',
    'T3XM': '10:10 AM',
    'T4XM': '11 AM',
    'T5XM': '11:10 AM',
    'T6XM': '12 PM',
    'T7XM': '1 PM',
    'T8XM': '2 PM',
    'T9XM': '3 PM',
    'T10XM': '4 PM',        
    'T11XM': '12-12:30PM',
    },
    'EDT_Evening_Track': {
    'ScheduleTrack': 'Track2',
    'TZXM': 'EDT',
    'TZTITLE': 'Evening Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '5 PM',
    'T2XM': '6 PM',
    'T3XM': '6:10 PM',
    'T4XM': '7 PM',
    'T5XM': '7:10 PM',
    'T6XM': '8 PM',
    'T7XM': '9 PM',
    'T8XM': '10 PM',
    'T9XM': '11 PM',
    'T10XM': '12 AM',
    'T11XM': '8-8:30PM', 
    },
    'EDT_Night_Poster_Session': {
    'ScheduleTrack': 'Track3',
    'TZXM': 'EDT',
    'TZTITLE': 'Night Poster Session',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '4 AM',
    'T2XM': '6 AM',
    'T3XM': '4-4:30 AM',
    'T4XM': '5-5:30 AM',
    },
    'CEST_Afternoon_Track': {
    'ScheduleTrack': 'Track1',
    'TZXM': 'CEST',
    'TZTITLE': 'Afternoon Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '3 PM',
    'T2XM': '4 PM',
    'T3XM': '4:10 PM',
    'T4XM': '5 PM',
    'T5XM': '5:10 PM',
    'T6XM': '6 PM',
    'T7XM': '7 PM',
    'T8XM': '8 PM',
    'T9XM': '9 PM',
    'T10XM': '10 PM',        
    'T11XM': '6-6:30PM',
    },
    'CEST_Night_Track': {
    'ScheduleTrack': 'Track2',
    'TZXM': 'CEST',
    'TZTITLE': 'Night Track',
    'TZD1': 'Tuesday, June 22',
    'TZD2': 'Wednesday, June 23',
    'TZD3': 'Thursday, June 24',
    'TZD4': 'Friday, June 25',
    'TZD5': 'Saturday, June 26',        
    'T1XM': '11 PM (prior day)',
    'T2XM': '12 AM',
    'T3XM': '12:10 AM',
    'T4XM': '1 AM',
    'T5XM': '1:10 AM',
    'T6XM': '2 AM',
    'T7XM': '3 AM',
    'T8XM': '4 AM',
    'T9XM': '5 AM',
    'T10XM': '6 AM',
    'T11XM': '2-2:30AM', 
    },
    'CEST_Morning_Poster_Session': {
    'ScheduleTrack': 'Track3',
    'TZXM': 'CEST',
    'TZTITLE': 'Morning Poster Session',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '10 AM',
    'T2XM': '12 PM',
    'T3XM': '10-10:30 AM',
    'T4XM': '11-11:30 AM',
    },
    'CST_Night_Track': {
    'ScheduleTrack': 'Track1',
    'TZXM': 'CST',
    'TZTITLE': 'Night Track',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '9 PM',
    'T2XM': '10 PM',
    'T3XM': '10:10 PM',
    'T4XM': '11 PM',
    'T5XM': '11:10 PM',
    'T6XM': '12 AM (next day)',
    'T7XM': '1 AM (next day)',
    'T8XM': '2 AM (next day)',
    'T9XM': '3 AM (next day)',
    'T10XM': '4 AM (next day)',
    'T11XM': '12-12:30AM',
    },
    'CST_Morning_Track': {
    'ScheduleTrack': 'Track2',
    'TZXM': 'CST',
    'TZTITLE': 'Morning Track',
    'TZD1': 'Tuesday, June 22',
    'TZD2': 'Wednesday, June 23',
    'TZD3': 'Thursday, June 24',
    'TZD4': 'Friday, June 25',
    'TZD5': 'Saturday, June 26',        
    'T1XM': '5 AM',
    'T2XM': '6 AM',
    'T3XM': '6:10 AM',
    'T4XM': '7 AM',
    'T5XM': '7:10 AM',
    'T6XM': '8 AM',
    'T7XM': '9 AM',
    'T8XM': '10 AM',
    'T9XM': '11 AM',
    'T10XM': '12 PM',
    'T11XM': '8-8:30AM', 
    },
    'CST_Afternoon_Poster_Session': {
    'ScheduleTrack': 'Track3',
    'TZXM': 'CST',
    'TZTITLE': 'Afternoon Poster Session',
    'TZD1': 'Monday, June 21',
    'TZD2': 'Tuesday, June 22',
    'TZD3': 'Wednesday, June 23',
    'TZD4': 'Thursday, June 24',
    'TZD5': 'Friday, June 25',
    'T1XM': '4 PM',
    'T2XM': '6 PM',
    'T3XM': '4-4:30 PM',
    'T4XM': '5-5:30 PM',
    },
}

# %%
for tz, _ in times.items():     
    filein = open("./OHBM2021_Schedule_at_a_glance_%s.svg" % times[tz]['ScheduleTrack'],"r+")
    filetxt = filein.read()
    filein.close()

    for item, replacement in times[tz].items():    
        filetxt = filetxt.replace(item, replacement)
    
    fileout = open("./OHBM2021_Schedule_at_a_glance_%s.svg" % tz, "w")
    fileout.write(filetxt)
    fileout.close()
